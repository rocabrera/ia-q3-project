# %%
import numpy as np
import pandas as pd
from funcs.model import MLP

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
df = pd.read_excel("data/Dry_Bean_Dataset.xlsx")

# %%
y = df["Class"]
y = y.astype("category").cat.codes
X = df.iloc[:,:-1]

#print(X)

#normalizando X
X = (X-X.min())/(X.max()-X.min())

#print(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,test_size=0.2, random_state=42)
print(type(X_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
class BeansDataset(Dataset):
    
    def __init__(self, X:np.array, y:np.array, transform=None):
        """
        Args:
            X: Features.
            y: target.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.X = X.astype('float32')
        self.y = y.astype('float32')
        
        ####
        #Inversao desnecessaria causava o primeiro erro
        ####
        #self.y = self.y.reshape((len(self.y), 1))
        
        self.n_samples = self.X.shape[0]
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, idx):
        
        sample = self.X[idx], self.y[idx]

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
batch_size = 1500

test_dataset = BeansDataset(X_test.to_numpy(), y_test.to_numpy())
train_dataset = BeansDataset(X_train.to_numpy(), y_train.to_numpy())

print(type(test_dataset))


# This will apply the softmax
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, shuffle=True, batch_size=batch_size)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, shuffle=True, batch_size=batch_size)
# Out:
# <class '__main__.BeansDataset'>

# %%
model = MLP(16,10,7)
device="cpu"
num_epochs=100
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss() # specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.Adam(model.parameters(),lr = 0.01)

# %%
n_total_steps = len(train_loader)
torch.set_printoptions(edgeitems=4)
for epoch in range(num_epochs):
    # enumerate mini batches
    for i, (inputs, targets) in enumerate(train_loader):
        inputs = inputs.to(device)
        #print(targets)
        ###
        #Outro problema aqui, os rotulos precisam ser indexes (ints), mas da forma construida eram tudo no formato de float
        ###
        targets = targets.to(device,dtype=torch.int64)
        #print(targets)
        # clear the gradients
        optimizer.zero_grad()
        # compute the model output
        yhat = model(inputs)
        # calculate loss
        #if i+1==2 or i+1==4:
        #    print(yhat)
        #print(targets)
        loss = criterion(yhat, targets)
        # credit assignment
        loss.backward()
        # update model weights
        optimizer.step()
        print(f"epoch {epoch + 1} / {num_epochs}, step {i + 1}/{n_total_steps}, loss = {loss.item():.4f}")
# Out:
# epoch 1 / 100, step 1/8, loss = 1.9130
# epoch 1 / 100, step 2/8, loss = 1.8977
# epoch 1 / 100, step 3/8, loss = 1.9036
# epoch 1 / 100, step 4/8, loss = 1.8754
# epoch 1 / 100, step 5/8, loss = 1.8630
# epoch 1 / 100, step 6/8, loss = 1.8583
# epoch 1 / 100, step 7/8, loss = 1.8336
# epoch 1 / 100, step 8/8, loss = 1.8226
# epoch 2 / 100, step 1/8, loss = 1.8139
# epoch 2 / 100, step 2/8, loss = 1.7883
# epoch 2 / 100, step 3/8, loss = 1.7795
# epoch 2 / 100, step 4/8, loss = 1.7619
# epoch 2 / 100, step 5/8, loss = 1.7414
# epoch 2 / 100, step 6/8, loss = 1.7349
# epoch 2 / 100, step 7/8, loss = 1.6979
# epoch 2 / 100, step 8/8, loss = 1.6528
# epoch 3 / 100, step 1/8, loss = 1.6500
# epoch 3 / 100, step 2/8, loss = 1.6201
# epoch 3 / 100, step 3/8, loss = 1.6233
# epoch 3 / 100, step 4/8, loss = 1.5809
# epoch 3 / 100, step 5/8, loss = 1.5830
# epoch 3 / 100, step 6/8, loss = 1.5573
# epoch 3 / 100, step 7/8, loss = 1.5131
# epoch 3 / 100, step 8/8, loss = 1.5278
# epoch 4 / 100, step 1/8, loss = 1.4851
# epoch 4 / 100, step 2/8, loss = 1.4362
# epoch 4 / 100, step 3/8, loss = 1.4308
# epoch 4 / 100, step 4/8, loss = 1.3947
# epoch 4 / 100, step 5/8, loss = 1.3953
# epoch 4 / 100, step 6/8, loss = 1.3653
# epoch 4 / 100, step 7/8, loss = 1.3161
# epoch 4 / 100, step 8/8, loss = 1.3346
# epoch 5 / 100, step 1/8, loss = 1.2931
# epoch 5 / 100, step 2/8, loss = 1.2658
# epoch 5 / 100, step 3/8, loss = 1.2553
# epoch 5 / 100, step 4/8, loss = 1.2372
# epoch 5 / 100, step 5/8, loss = 1.1907
# epoch 5 / 100, step 6/8, loss = 1.1778
# epoch 5 / 100, step 7/8, loss = 1.1687
# epoch 5 / 100, step 8/8, loss = 1.1723
# epoch 6 / 100, step 1/8, loss = 1.1341
# epoch 6 / 100, step 2/8, loss = 1.0954
# epoch 6 / 100, step 3/8, loss = 1.0978
# epoch 6 / 100, step 4/8, loss = 1.0785
# epoch 6 / 100, step 5/8, loss = 1.0473
# epoch 6 / 100, step 6/8, loss = 1.0272
# epoch 6 / 100, step 7/8, loss = 1.0025
# epoch 6 / 100, step 8/8, loss = 0.9677
# epoch 7 / 100, step 1/8, loss = 0.9894
# epoch 7 / 100, step 2/8, loss = 0.9587
# epoch 7 / 100, step 3/8, loss = 0.9501
# epoch 7 / 100, step 4/8, loss = 0.9434
# epoch 7 / 100, step 5/8, loss = 0.9083
# epoch 7 / 100, step 6/8, loss = 0.8667
# epoch 7 / 100, step 7/8, loss = 0.8746
# epoch 7 / 100, step 8/8, loss = 0.8725
# epoch 8 / 100, step 1/8, loss = 0.8483
# epoch 8 / 100, step 2/8, loss = 0.8271
# epoch 8 / 100, step 3/8, loss = 0.8131
# epoch 8 / 100, step 4/8, loss = 0.8084
# epoch 8 / 100, step 5/8, loss = 0.7848
# epoch 8 / 100, step 6/8, loss = 0.7946
# epoch 8 / 100, step 7/8, loss = 0.7676
# epoch 8 / 100, step 8/8, loss = 0.7666
# epoch 9 / 100, step 1/8, loss = 0.7409
# epoch 9 / 100, step 2/8, loss = 0.7472
# epoch 9 / 100, step 3/8, loss = 0.7114
# epoch 9 / 100, step 4/8, loss = 0.7005
# epoch 9 / 100, step 5/8, loss = 0.6883
# epoch 9 / 100, step 6/8, loss = 0.6816
# epoch 9 / 100, step 7/8, loss = 0.6763
# epoch 9 / 100, step 8/8, loss = 0.6458
# epoch 10 / 100, step 1/8, loss = 0.6392
# epoch 10 / 100, step 2/8, loss = 0.6516
# epoch 10 / 100, step 3/8, loss = 0.6332
# epoch 10 / 100, step 4/8, loss = 0.6283
# epoch 10 / 100, step 5/8, loss = 0.6102
# epoch 10 / 100, step 6/8, loss = 0.6142
# epoch 10 / 100, step 7/8, loss = 0.6051
# epoch 10 / 100, step 8/8, loss = 0.5930
# epoch 11 / 100, step 1/8, loss = 0.5942
# epoch 11 / 100, step 2/8, loss = 0.5818
# epoch 11 / 100, step 3/8, loss = 0.5559
# epoch 11 / 100, step 4/8, loss = 0.5600
# epoch 11 / 100, step 5/8, loss = 0.5437
# epoch 11 / 100, step 6/8, loss = 0.5419
# epoch 11 / 100, step 7/8, loss = 0.5410
# epoch 11 / 100, step 8/8, loss = 0.5823
# epoch 12 / 100, step 1/8, loss = 0.5162
# epoch 12 / 100, step 2/8, loss = 0.5256
# epoch 12 / 100, step 3/8, loss = 0.5074
# epoch 12 / 100, step 4/8, loss = 0.5114
# epoch 12 / 100, step 5/8, loss = 0.5017
# epoch 12 / 100, step 6/8, loss = 0.5136
# epoch 12 / 100, step 7/8, loss = 0.5044
# epoch 12 / 100, step 8/8, loss = 0.4930
# epoch 13 / 100, step 1/8, loss = 0.4805
# epoch 13 / 100, step 2/8, loss = 0.4768
# epoch 13 / 100, step 3/8, loss = 0.4703
# epoch 13 / 100, step 4/8, loss = 0.4765
# epoch 13 / 100, step 5/8, loss = 0.4736
# epoch 13 / 100, step 6/8, loss = 0.4617
# epoch 13 / 100, step 7/8, loss = 0.4691
# epoch 13 / 100, step 8/8, loss = 0.4380
# epoch 14 / 100, step 1/8, loss = 0.4356
# epoch 14 / 100, step 2/8, loss = 0.4475
# epoch 14 / 100, step 3/8, loss = 0.4260
# epoch 14 / 100, step 4/8, loss = 0.4528
# epoch 14 / 100, step 5/8, loss = 0.4515
# epoch 14 / 100, step 6/8, loss = 0.4498
# epoch 14 / 100, step 7/8, loss = 0.4317
# epoch 14 / 100, step 8/8, loss = 0.4162
# epoch 15 / 100, step 1/8, loss = 0.4150
# epoch 15 / 100, step 2/8, loss = 0.4218
# epoch 15 / 100, step 3/8, loss = 0.4230
# epoch 15 / 100, step 4/8, loss = 0.4248
# epoch 15 / 100, step 5/8, loss = 0.4176
# epoch 15 / 100, step 6/8, loss = 0.4031
# epoch 15 / 100, step 7/8, loss = 0.4015
# epoch 15 / 100, step 8/8, loss = 0.4263
# epoch 16 / 100, step 1/8, loss = 0.3922
# epoch 16 / 100, step 2/8, loss = 0.3955
# epoch 16 / 100, step 3/8, loss = 0.4047
# epoch 16 / 100, step 4/8, loss = 0.4094
# epoch 16 / 100, step 5/8, loss = 0.3883
# epoch 16 / 100, step 6/8, loss = 0.4000
# epoch 16 / 100, step 7/8, loss = 0.3805
# epoch 16 / 100, step 8/8, loss = 0.3779
# epoch 17 / 100, step 1/8, loss = 0.3716
# epoch 17 / 100, step 2/8, loss = 0.3753
# epoch 17 / 100, step 3/8, loss = 0.3938
# epoch 17 / 100, step 4/8, loss = 0.3639
# epoch 17 / 100, step 5/8, loss = 0.3860
# epoch 17 / 100, step 6/8, loss = 0.3762
# epoch 17 / 100, step 7/8, loss = 0.3843
# epoch 17 / 100, step 8/8, loss = 0.3675
# epoch 18 / 100, step 1/8, loss = 0.3713
# epoch 18 / 100, step 2/8, loss = 0.3863
# epoch 18 / 100, step 3/8, loss = 0.3613
# epoch 18 / 100, step 4/8, loss = 0.3576
# epoch 18 / 100, step 5/8, loss = 0.3669
# epoch 18 / 100, step 6/8, loss = 0.3625
# epoch 18 / 100, step 7/8, loss = 0.3365
# epoch 18 / 100, step 8/8, loss = 0.3939
# epoch 19 / 100, step 1/8, loss = 0.3580
# epoch 19 / 100, step 2/8, loss = 0.3915
# epoch 19 / 100, step 3/8, loss = 0.3457
# epoch 19 / 100, step 4/8, loss = 0.3406
# epoch 19 / 100, step 5/8, loss = 0.3400
# epoch 19 / 100, step 6/8, loss = 0.3426
# epoch 19 / 100, step 7/8, loss = 0.3490
# epoch 19 / 100, step 8/8, loss = 0.3820
# epoch 20 / 100, step 1/8, loss = 0.3564
# epoch 20 / 100, step 2/8, loss = 0.3186
# epoch 20 / 100, step 3/8, loss = 0.3198
# epoch 20 / 100, step 4/8, loss = 0.3408
# epoch 20 / 100, step 5/8, loss = 0.3841
# epoch 20 / 100, step 6/8, loss = 0.3478
# epoch 20 / 100, step 7/8, loss = 0.3416
# epoch 20 / 100, step 8/8, loss = 0.3282
# epoch 21 / 100, step 1/8, loss = 0.3407
# epoch 21 / 100, step 2/8, loss = 0.3410
# epoch 21 / 100, step 3/8, loss = 0.3454
# epoch 21 / 100, step 4/8, loss = 0.3203
# epoch 21 / 100, step 5/8, loss = 0.3340
# epoch 21 / 100, step 6/8, loss = 0.3244
# epoch 21 / 100, step 7/8, loss = 0.3480
# epoch 21 / 100, step 8/8, loss = 0.3244
# epoch 22 / 100, step 1/8, loss = 0.3370
# epoch 22 / 100, step 2/8, loss = 0.3240
# epoch 22 / 100, step 3/8, loss = 0.3393
# epoch 22 / 100, step 4/8, loss = 0.3311
# epoch 22 / 100, step 5/8, loss = 0.3210
# epoch 22 / 100, step 6/8, loss = 0.3152
# epoch 22 / 100, step 7/8, loss = 0.3329
# epoch 22 / 100, step 8/8, loss = 0.3260
# epoch 23 / 100, step 1/8, loss = 0.3404
# epoch 23 / 100, step 2/8, loss = 0.3222
# epoch 23 / 100, step 3/8, loss = 0.3327
# epoch 23 / 100, step 4/8, loss = 0.3170
# epoch 23 / 100, step 5/8, loss = 0.3286
# epoch 23 / 100, step 6/8, loss = 0.3186
# epoch 23 / 100, step 7/8, loss = 0.3036
# epoch 23 / 100, step 8/8, loss = 0.3101
# epoch 24 / 100, step 1/8, loss = 0.3635
# epoch 24 / 100, step 2/8, loss = 0.2990
# epoch 24 / 100, step 3/8, loss = 0.3134
# epoch 24 / 100, step 4/8, loss = 0.3137
# epoch 24 / 100, step 5/8, loss = 0.3111
# epoch 24 / 100, step 6/8, loss = 0.3163
# epoch 24 / 100, step 7/8, loss = 0.3148
# epoch 24 / 100, step 8/8, loss = 0.2801
# epoch 25 / 100, step 1/8, loss = 0.3338
# epoch 25 / 100, step 2/8, loss = 0.3397
# epoch 25 / 100, step 3/8, loss = 0.2918
# epoch 25 / 100, step 4/8, loss = 0.3136
# epoch 25 / 100, step 5/8, loss = 0.3088
# epoch 25 / 100, step 6/8, loss = 0.2979
# epoch 25 / 100, step 7/8, loss = 0.3155
# epoch 25 / 100, step 8/8, loss = 0.2756
# epoch 26 / 100, step 1/8, loss = 0.3037
# epoch 26 / 100, step 2/8, loss = 0.2860
# epoch 26 / 100, step 3/8, loss = 0.3246
# epoch 26 / 100, step 4/8, loss = 0.3250
# epoch 26 / 100, step 5/8, loss = 0.3278
# epoch 26 / 100, step 6/8, loss = 0.3110
# epoch 26 / 100, step 7/8, loss = 0.2873
# epoch 26 / 100, step 8/8, loss = 0.3140
# epoch 27 / 100, step 1/8, loss = 0.3236
# epoch 27 / 100, step 2/8, loss = 0.2972
# epoch 27 / 100, step 3/8, loss = 0.3116
# epoch 27 / 100, step 4/8, loss = 0.3055
# epoch 27 / 100, step 5/8, loss = 0.2965
# epoch 27 / 100, step 6/8, loss = 0.2884
# epoch 27 / 100, step 7/8, loss = 0.3017
# epoch 27 / 100, step 8/8, loss = 0.3527
# epoch 28 / 100, step 1/8, loss = 0.3323
# epoch 28 / 100, step 2/8, loss = 0.2855
# epoch 28 / 100, step 3/8, loss = 0.2984
# epoch 28 / 100, step 4/8, loss = 0.2947
# epoch 28 / 100, step 5/8, loss = 0.3002
# epoch 28 / 100, step 6/8, loss = 0.2968
# epoch 28 / 100, step 7/8, loss = 0.3021
# epoch 28 / 100, step 8/8, loss = 0.3165
# epoch 29 / 100, step 1/8, loss = 0.3161
# epoch 29 / 100, step 2/8, loss = 0.3204
# epoch 29 / 100, step 3/8, loss = 0.2799
# epoch 29 / 100, step 4/8, loss = 0.3039
# epoch 29 / 100, step 5/8, loss = 0.2851
# epoch 29 / 100, step 6/8, loss = 0.2978
# epoch 29 / 100, step 7/8, loss = 0.3010
# epoch 29 / 100, step 8/8, loss = 0.2538
# epoch 30 / 100, step 1/8, loss = 0.3125
# epoch 30 / 100, step 2/8, loss = 0.2984
# epoch 30 / 100, step 3/8, loss = 0.3144
# epoch 30 / 100, step 4/8, loss = 0.2865
# epoch 30 / 100, step 5/8, loss = 0.3038
# epoch 30 / 100, step 6/8, loss = 0.2568
# epoch 30 / 100, step 7/8, loss = 0.3075
# epoch 30 / 100, step 8/8, loss = 0.2334
# epoch 31 / 100, step 1/8, loss = 0.3069
# epoch 31 / 100, step 2/8, loss = 0.3074
# epoch 31 / 100, step 3/8, loss = 0.2747
# epoch 31 / 100, step 4/8, loss = 0.2968
# epoch 31 / 100, step 5/8, loss = 0.3084
# epoch 31 / 100, step 6/8, loss = 0.2636
# epoch 31 / 100, step 7/8, loss = 0.2810
# epoch 31 / 100, step 8/8, loss = 0.3301
# epoch 32 / 100, step 1/8, loss = 0.2879
# epoch 32 / 100, step 2/8, loss = 0.3099
# epoch 32 / 100, step 3/8, loss = 0.2795
# epoch 32 / 100, step 4/8, loss = 0.3011
# epoch 32 / 100, step 5/8, loss = 0.2815
# epoch 32 / 100, step 6/8, loss = 0.2650
# epoch 32 / 100, step 7/8, loss = 0.3066
# epoch 32 / 100, step 8/8, loss = 0.3163
# epoch 33 / 100, step 1/8, loss = 0.2866
# epoch 33 / 100, step 2/8, loss = 0.3174
# epoch 33 / 100, step 3/8, loss = 0.2433
# epoch 33 / 100, step 4/8, loss = 0.2814
# epoch 33 / 100, step 5/8, loss = 0.2818
# epoch 33 / 100, step 6/8, loss = 0.2940
# epoch 33 / 100, step 7/8, loss = 0.3086
# epoch 33 / 100, step 8/8, loss = 0.3057
# epoch 34 / 100, step 1/8, loss = 0.2907
# epoch 34 / 100, step 2/8, loss = 0.2950
# epoch 34 / 100, step 3/8, loss = 0.2700
# epoch 34 / 100, step 4/8, loss = 0.2789
# epoch 34 / 100, step 5/8, loss = 0.2981
# epoch 34 / 100, step 6/8, loss = 0.2744
# epoch 34 / 100, step 7/8, loss = 0.2873
# epoch 34 / 100, step 8/8, loss = 0.3017
# epoch 35 / 100, step 1/8, loss = 0.3067
# epoch 35 / 100, step 2/8, loss = 0.2889
# epoch 35 / 100, step 3/8, loss = 0.2728
# epoch 35 / 100, step 4/8, loss = 0.2749
# epoch 35 / 100, step 5/8, loss = 0.2819
# epoch 35 / 100, step 6/8, loss = 0.2816
# epoch 35 / 100, step 7/8, loss = 0.2683
# epoch 35 / 100, step 8/8, loss = 0.3121
# epoch 36 / 100, step 1/8, loss = 0.2583
# epoch 36 / 100, step 2/8, loss = 0.2916
# epoch 36 / 100, step 3/8, loss = 0.2763
# epoch 36 / 100, step 4/8, loss = 0.2588
# epoch 36 / 100, step 5/8, loss = 0.2917
# epoch 36 / 100, step 6/8, loss = 0.3005
# epoch 36 / 100, step 7/8, loss = 0.2842
# epoch 36 / 100, step 8/8, loss = 0.3129
# epoch 37 / 100, step 1/8, loss = 0.2726
# epoch 37 / 100, step 2/8, loss = 0.2650
# epoch 37 / 100, step 3/8, loss = 0.2728
# epoch 37 / 100, step 4/8, loss = 0.2750
# epoch 37 / 100, step 5/8, loss = 0.2733
# epoch 37 / 100, step 6/8, loss = 0.3038
# epoch 37 / 100, step 7/8, loss = 0.3002
# epoch 37 / 100, step 8/8, loss = 0.2661
# epoch 38 / 100, step 1/8, loss = 0.2734
# epoch 38 / 100, step 2/8, loss = 0.2881
# epoch 38 / 100, step 3/8, loss = 0.2881
# epoch 38 / 100, step 4/8, loss = 0.2740
# epoch 38 / 100, step 5/8, loss = 0.2734
# epoch 38 / 100, step 6/8, loss = 0.2900
# epoch 38 / 100, step 7/8, loss = 0.2601
# epoch 38 / 100, step 8/8, loss = 0.2717
# epoch 39 / 100, step 1/8, loss = 0.2738
# epoch 39 / 100, step 2/8, loss = 0.2659
# epoch 39 / 100, step 3/8, loss = 0.2838
# epoch 39 / 100, step 4/8, loss = 0.2707
# epoch 39 / 100, step 5/8, loss = 0.2926
# epoch 39 / 100, step 6/8, loss = 0.2860
# epoch 39 / 100, step 7/8, loss = 0.2718
# epoch 39 / 100, step 8/8, loss = 0.2468
# epoch 40 / 100, step 1/8, loss = 0.2808
# epoch 40 / 100, step 2/8, loss = 0.2484
# epoch 40 / 100, step 3/8, loss = 0.2813
# epoch 40 / 100, step 4/8, loss = 0.2886
# epoch 40 / 100, step 5/8, loss = 0.2739
# epoch 40 / 100, step 6/8, loss = 0.2554
# epoch 40 / 100, step 7/8, loss = 0.2863
# epoch 40 / 100, step 8/8, loss = 0.2887
# epoch 41 / 100, step 1/8, loss = 0.2637
# epoch 41 / 100, step 2/8, loss = 0.2494
# epoch 41 / 100, step 3/8, loss = 0.2670
# epoch 41 / 100, step 4/8, loss = 0.2830
# epoch 41 / 100, step 5/8, loss = 0.2697
# epoch 41 / 100, step 6/8, loss = 0.2861
# epoch 41 / 100, step 7/8, loss = 0.2737
# epoch 41 / 100, step 8/8, loss = 0.2940
# epoch 42 / 100, step 1/8, loss = 0.2507
# epoch 42 / 100, step 2/8, loss = 0.2616
# epoch 42 / 100, step 3/8, loss = 0.2562
# epoch 42 / 100, step 4/8, loss = 0.2820
# epoch 42 / 100, step 5/8, loss = 0.2847
# epoch 42 / 100, step 6/8, loss = 0.2854
# epoch 42 / 100, step 7/8, loss = 0.2734
# epoch 42 / 100, step 8/8, loss = 0.2800
# epoch 43 / 100, step 1/8, loss = 0.2367
# epoch 43 / 100, step 2/8, loss = 0.2764
# epoch 43 / 100, step 3/8, loss = 0.2645
# epoch 43 / 100, step 4/8, loss = 0.3225
# epoch 43 / 100, step 5/8, loss = 0.2639
# epoch 43 / 100, step 6/8, loss = 0.2674
# epoch 43 / 100, step 7/8, loss = 0.2461
# epoch 43 / 100, step 8/8, loss = 0.2803
# epoch 44 / 100, step 1/8, loss = 0.2717
# epoch 44 / 100, step 2/8, loss = 0.2697
# epoch 44 / 100, step 3/8, loss = 0.2663
# epoch 44 / 100, step 4/8, loss = 0.2978
# epoch 44 / 100, step 5/8, loss = 0.2780
# epoch 44 / 100, step 6/8, loss = 0.2576
# epoch 44 / 100, step 7/8, loss = 0.2393
# epoch 44 / 100, step 8/8, loss = 0.2756
# epoch 45 / 100, step 1/8, loss = 0.2668
# epoch 45 / 100, step 2/8, loss = 0.2683
# epoch 45 / 100, step 3/8, loss = 0.2615
# epoch 45 / 100, step 4/8, loss = 0.2639
# epoch 45 / 100, step 5/8, loss = 0.2883
# epoch 45 / 100, step 6/8, loss = 0.2622
# epoch 45 / 100, step 7/8, loss = 0.2680
# epoch 45 / 100, step 8/8, loss = 0.2452
# epoch 46 / 100, step 1/8, loss = 0.2798
# epoch 46 / 100, step 2/8, loss = 0.2791
# epoch 46 / 100, step 3/8, loss = 0.2356
# epoch 46 / 100, step 4/8, loss = 0.2765
# epoch 46 / 100, step 5/8, loss = 0.2810
# epoch 46 / 100, step 6/8, loss = 0.2590
# epoch 46 / 100, step 7/8, loss = 0.2566
# epoch 46 / 100, step 8/8, loss = 0.2931
# epoch 47 / 100, step 1/8, loss = 0.2616
# epoch 47 / 100, step 2/8, loss = 0.2994
# epoch 47 / 100, step 3/8, loss = 0.2744
# epoch 47 / 100, step 4/8, loss = 0.2495
# epoch 47 / 100, step 5/8, loss = 0.2466
# epoch 47 / 100, step 6/8, loss = 0.2565
# epoch 47 / 100, step 7/8, loss = 0.2703
# epoch 47 / 100, step 8/8, loss = 0.2575
# epoch 48 / 100, step 1/8, loss = 0.2675
# epoch 48 / 100, step 2/8, loss = 0.2302
# epoch 48 / 100, step 3/8, loss = 0.2838
# epoch 48 / 100, step 4/8, loss = 0.2647
# epoch 48 / 100, step 5/8, loss = 0.2586
# epoch 48 / 100, step 6/8, loss = 0.2799
# epoch 48 / 100, step 7/8, loss = 0.2638
# epoch 48 / 100, step 8/8, loss = 0.2494
# epoch 49 / 100, step 1/8, loss = 0.2654
# epoch 49 / 100, step 2/8, loss = 0.2960
# epoch 49 / 100, step 3/8, loss = 0.2245
# epoch 49 / 100, step 4/8, loss = 0.2265
# epoch 49 / 100, step 5/8, loss = 0.2871
# epoch 49 / 100, step 6/8, loss = 0.2628
# epoch 49 / 100, step 7/8, loss = 0.2732
# epoch 49 / 100, step 8/8, loss = 0.2823
# epoch 50 / 100, step 1/8, loss = 0.2630
# epoch 50 / 100, step 2/8, loss = 0.2551
# epoch 50 / 100, step 3/8, loss = 0.2218
# epoch 50 / 100, step 4/8, loss = 0.2419
# epoch 50 / 100, step 5/8, loss = 0.2698
# epoch 50 / 100, step 6/8, loss = 0.2778
# epoch 50 / 100, step 7/8, loss = 0.2791
# epoch 50 / 100, step 8/8, loss = 0.2697
# epoch 51 / 100, step 1/8, loss = 0.2675
# epoch 51 / 100, step 2/8, loss = 0.2544
# epoch 51 / 100, step 3/8, loss = 0.2631
# epoch 51 / 100, step 4/8, loss = 0.2731
# epoch 51 / 100, step 5/8, loss = 0.2366
# epoch 51 / 100, step 6/8, loss = 0.2638
# epoch 51 / 100, step 7/8, loss = 0.2431
# epoch 51 / 100, step 8/8, loss = 0.2564
# epoch 52 / 100, step 1/8, loss = 0.2603
# epoch 52 / 100, step 2/8, loss = 0.2549
# epoch 52 / 100, step 3/8, loss = 0.2484
# epoch 52 / 100, step 4/8, loss = 0.2432
# epoch 52 / 100, step 5/8, loss = 0.2736
# epoch 52 / 100, step 6/8, loss = 0.2652
# epoch 52 / 100, step 7/8, loss = 0.2458
# epoch 52 / 100, step 8/8, loss = 0.2673
# epoch 53 / 100, step 1/8, loss = 0.2403
# epoch 53 / 100, step 2/8, loss = 0.2697
# epoch 53 / 100, step 3/8, loss = 0.2722
# epoch 53 / 100, step 4/8, loss = 0.2598
# epoch 53 / 100, step 5/8, loss = 0.2548
# epoch 53 / 100, step 6/8, loss = 0.2475
# epoch 53 / 100, step 7/8, loss = 0.2366
# epoch 53 / 100, step 8/8, loss = 0.2915
# epoch 54 / 100, step 1/8, loss = 0.2583
# epoch 54 / 100, step 2/8, loss = 0.2285
# epoch 54 / 100, step 3/8, loss = 0.2600
# epoch 54 / 100, step 4/8, loss = 0.2740
# epoch 54 / 100, step 5/8, loss = 0.2533
# epoch 54 / 100, step 6/8, loss = 0.2567
# epoch 54 / 100, step 7/8, loss = 0.2498
# epoch 54 / 100, step 8/8, loss = 0.2817
# epoch 55 / 100, step 1/8, loss = 0.2577
# epoch 55 / 100, step 2/8, loss = 0.2555
# epoch 55 / 100, step 3/8, loss = 0.2498
# epoch 55 / 100, step 4/8, loss = 0.2342
# epoch 55 / 100, step 5/8, loss = 0.2807
# epoch 55 / 100, step 6/8, loss = 0.2676
# epoch 55 / 100, step 7/8, loss = 0.2565
# epoch 55 / 100, step 8/8, loss = 0.2134
# epoch 56 / 100, step 1/8, loss = 0.2465
# epoch 56 / 100, step 2/8, loss = 0.2636
# epoch 56 / 100, step 3/8, loss = 0.2828
# epoch 56 / 100, step 4/8, loss = 0.2640
# epoch 56 / 100, step 5/8, loss = 0.2406
# epoch 56 / 100, step 6/8, loss = 0.2282
# epoch 56 / 100, step 7/8, loss = 0.2407
# epoch 56 / 100, step 8/8, loss = 0.2750
# epoch 57 / 100, step 1/8, loss = 0.2591
# epoch 57 / 100, step 2/8, loss = 0.2625
# epoch 57 / 100, step 3/8, loss = 0.2450
# epoch 57 / 100, step 4/8, loss = 0.2483
# epoch 57 / 100, step 5/8, loss = 0.2562
# epoch 57 / 100, step 6/8, loss = 0.2248
# epoch 57 / 100, step 7/8, loss = 0.2714
# epoch 57 / 100, step 8/8, loss = 0.2431
# epoch 58 / 100, step 1/8, loss = 0.2789
# epoch 58 / 100, step 2/8, loss = 0.2609
# epoch 58 / 100, step 3/8, loss = 0.2320
# epoch 58 / 100, step 4/8, loss = 0.2535
# epoch 58 / 100, step 5/8, loss = 0.2613
# epoch 58 / 100, step 6/8, loss = 0.2425
# epoch 58 / 100, step 7/8, loss = 0.2398
# epoch 58 / 100, step 8/8, loss = 0.2456
# epoch 59 / 100, step 1/8, loss = 0.2468
# epoch 59 / 100, step 2/8, loss = 0.2548
# epoch 59 / 100, step 3/8, loss = 0.2453
# epoch 59 / 100, step 4/8, loss = 0.2154
# epoch 59 / 100, step 5/8, loss = 0.2842
# epoch 59 / 100, step 6/8, loss = 0.2575
# epoch 59 / 100, step 7/8, loss = 0.2454
# epoch 59 / 100, step 8/8, loss = 0.2747
# epoch 60 / 100, step 1/8, loss = 0.2844
# epoch 60 / 100, step 2/8, loss = 0.2419
# epoch 60 / 100, step 3/8, loss = 0.2663
# epoch 60 / 100, step 4/8, loss = 0.2430
# epoch 60 / 100, step 5/8, loss = 0.2424
# epoch 60 / 100, step 6/8, loss = 0.2381
# epoch 60 / 100, step 7/8, loss = 0.2449
# epoch 60 / 100, step 8/8, loss = 0.2285
# epoch 61 / 100, step 1/8, loss = 0.2530
# epoch 61 / 100, step 2/8, loss = 0.2539
# epoch 61 / 100, step 3/8, loss = 0.2404
# epoch 61 / 100, step 4/8, loss = 0.2430
# epoch 61 / 100, step 5/8, loss = 0.2610
# epoch 61 / 100, step 6/8, loss = 0.2309
# epoch 61 / 100, step 7/8, loss = 0.2344
# epoch 61 / 100, step 8/8, loss = 0.3297
# epoch 62 / 100, step 1/8, loss = 0.2671
# epoch 62 / 100, step 2/8, loss = 0.2177
# epoch 62 / 100, step 3/8, loss = 0.2788
# epoch 62 / 100, step 4/8, loss = 0.2287
# epoch 62 / 100, step 5/8, loss = 0.2615
# epoch 62 / 100, step 6/8, loss = 0.2238
# epoch 62 / 100, step 7/8, loss = 0.2417
# epoch 62 / 100, step 8/8, loss = 0.2702
# epoch 63 / 100, step 1/8, loss = 0.2283
# epoch 63 / 100, step 2/8, loss = 0.2548
# epoch 63 / 100, step 3/8, loss = 0.2668
# epoch 63 / 100, step 4/8, loss = 0.2420
# epoch 63 / 100, step 5/8, loss = 0.2544
# epoch 63 / 100, step 6/8, loss = 0.2237
# epoch 63 / 100, step 7/8, loss = 0.2489
# epoch 63 / 100, step 8/8, loss = 0.2679
# epoch 64 / 100, step 1/8, loss = 0.2194
# epoch 64 / 100, step 2/8, loss = 0.2712
# epoch 64 / 100, step 3/8, loss = 0.2257
# epoch 64 / 100, step 4/8, loss = 0.2557
# epoch 64 / 100, step 5/8, loss = 0.2518
# epoch 64 / 100, step 6/8, loss = 0.2632
# epoch 64 / 100, step 7/8, loss = 0.2402
# epoch 64 / 100, step 8/8, loss = 0.2252
# epoch 65 / 100, step 1/8, loss = 0.2675
# epoch 65 / 100, step 2/8, loss = 0.2392
# epoch 65 / 100, step 3/8, loss = 0.2499
# epoch 65 / 100, step 4/8, loss = 0.2355
# epoch 65 / 100, step 5/8, loss = 0.2358
# epoch 65 / 100, step 6/8, loss = 0.2554
# epoch 65 / 100, step 7/8, loss = 0.2359
# epoch 65 / 100, step 8/8, loss = 0.2302
# epoch 66 / 100, step 1/8, loss = 0.2510
# epoch 66 / 100, step 2/8, loss = 0.2430
# epoch 66 / 100, step 3/8, loss = 0.2527
# epoch 66 / 100, step 4/8, loss = 0.2412
# epoch 66 / 100, step 5/8, loss = 0.2508
# epoch 66 / 100, step 6/8, loss = 0.2505
# epoch 66 / 100, step 7/8, loss = 0.2227
# epoch 66 / 100, step 8/8, loss = 0.2653
# epoch 67 / 100, step 1/8, loss = 0.2230
# epoch 67 / 100, step 2/8, loss = 0.2517
# epoch 67 / 100, step 3/8, loss = 0.2397
# epoch 67 / 100, step 4/8, loss = 0.2588
# epoch 67 / 100, step 5/8, loss = 0.2713
# epoch 67 / 100, step 6/8, loss = 0.2291
# epoch 67 / 100, step 7/8, loss = 0.2422
# epoch 67 / 100, step 8/8, loss = 0.2089
# epoch 68 / 100, step 1/8, loss = 0.2304
# epoch 68 / 100, step 2/8, loss = 0.2434
# epoch 68 / 100, step 3/8, loss = 0.2507
# epoch 68 / 100, step 4/8, loss = 0.2266
# epoch 68 / 100, step 5/8, loss = 0.2433
# epoch 68 / 100, step 6/8, loss = 0.2470
# epoch 68 / 100, step 7/8, loss = 0.2742
# epoch 68 / 100, step 8/8, loss = 0.2144
# epoch 69 / 100, step 1/8, loss = 0.2328
# epoch 69 / 100, step 2/8, loss = 0.2353
# epoch 69 / 100, step 3/8, loss = 0.2533
# epoch 69 / 100, step 4/8, loss = 0.2665
# epoch 69 / 100, step 5/8, loss = 0.2318
# epoch 69 / 100, step 6/8, loss = 0.1972
# epoch 69 / 100, step 7/8, loss = 0.2764
# epoch 69 / 100, step 8/8, loss = 0.2706
# epoch 70 / 100, step 1/8, loss = 0.2358
# epoch 70 / 100, step 2/8, loss = 0.2246
# epoch 70 / 100, step 3/8, loss = 0.2522
# epoch 70 / 100, step 4/8, loss = 0.2344
# epoch 70 / 100, step 5/8, loss = 0.2591
# epoch 70 / 100, step 6/8, loss = 0.2278
# epoch 70 / 100, step 7/8, loss = 0.2580
# epoch 70 / 100, step 8/8, loss = 0.2705
# epoch 71 / 100, step 1/8, loss = 0.2505
# epoch 71 / 100, step 2/8, loss = 0.2496
# epoch 71 / 100, step 3/8, loss = 0.2455
# epoch 71 / 100, step 4/8, loss = 0.2285
# epoch 71 / 100, step 5/8, loss = 0.2559
# epoch 71 / 100, step 6/8, loss = 0.2268
# epoch 71 / 100, step 7/8, loss = 0.2353
# epoch 71 / 100, step 8/8, loss = 0.2253
# epoch 72 / 100, step 1/8, loss = 0.2242
# epoch 72 / 100, step 2/8, loss = 0.2568
# epoch 72 / 100, step 3/8, loss = 0.2499
# epoch 72 / 100, step 4/8, loss = 0.2320
# epoch 72 / 100, step 5/8, loss = 0.2344
# epoch 72 / 100, step 6/8, loss = 0.2287
# epoch 72 / 100, step 7/8, loss = 0.2573
# epoch 72 / 100, step 8/8, loss = 0.2331
# epoch 73 / 100, step 1/8, loss = 0.2323
# epoch 73 / 100, step 2/8, loss = 0.2313
# epoch 73 / 100, step 3/8, loss = 0.2324
# epoch 73 / 100, step 4/8, loss = 0.2424
# epoch 73 / 100, step 5/8, loss = 0.2414
# epoch 73 / 100, step 6/8, loss = 0.2551
# epoch 73 / 100, step 7/8, loss = 0.2386
# epoch 73 / 100, step 8/8, loss = 0.2640
# epoch 74 / 100, step 1/8, loss = 0.2248
# epoch 74 / 100, step 2/8, loss = 0.2657
# epoch 74 / 100, step 3/8, loss = 0.2081
# epoch 74 / 100, step 4/8, loss = 0.2546
# epoch 74 / 100, step 5/8, loss = 0.2365
# epoch 74 / 100, step 6/8, loss = 0.2529
# epoch 74 / 100, step 7/8, loss = 0.2307
# epoch 74 / 100, step 8/8, loss = 0.2463
# epoch 75 / 100, step 1/8, loss = 0.2243
# epoch 75 / 100, step 2/8, loss = 0.2573
# epoch 75 / 100, step 3/8, loss = 0.2364
# epoch 75 / 100, step 4/8, loss = 0.2399
# epoch 75 / 100, step 5/8, loss = 0.2356
# epoch 75 / 100, step 6/8, loss = 0.2295
# epoch 75 / 100, step 7/8, loss = 0.2482
# epoch 75 / 100, step 8/8, loss = 0.2688
# epoch 76 / 100, step 1/8, loss = 0.2291
# epoch 76 / 100, step 2/8, loss = 0.2663
# epoch 76 / 100, step 3/8, loss = 0.2458
# epoch 76 / 100, step 4/8, loss = 0.2407
# epoch 76 / 100, step 5/8, loss = 0.2497
# epoch 76 / 100, step 6/8, loss = 0.2311
# epoch 76 / 100, step 7/8, loss = 0.2313
# epoch 76 / 100, step 8/8, loss = 0.2097
# epoch 77 / 100, step 1/8, loss = 0.2114
# epoch 77 / 100, step 2/8, loss = 0.2285
# epoch 77 / 100, step 3/8, loss = 0.2684
# epoch 77 / 100, step 4/8, loss = 0.2907
# epoch 77 / 100, step 5/8, loss = 0.2196
# epoch 77 / 100, step 6/8, loss = 0.2231
# epoch 77 / 100, step 7/8, loss = 0.2491
# epoch 77 / 100, step 8/8, loss = 0.2277
# epoch 78 / 100, step 1/8, loss = 0.2346
# epoch 78 / 100, step 2/8, loss = 0.2197
# epoch 78 / 100, step 3/8, loss = 0.2564
# epoch 78 / 100, step 4/8, loss = 0.2330
# epoch 78 / 100, step 5/8, loss = 0.2417
# epoch 78 / 100, step 6/8, loss = 0.2561
# epoch 78 / 100, step 7/8, loss = 0.2217
# epoch 78 / 100, step 8/8, loss = 0.2747
# epoch 79 / 100, step 1/8, loss = 0.2773
# epoch 79 / 100, step 2/8, loss = 0.2373
# epoch 79 / 100, step 3/8, loss = 0.2385
# epoch 79 / 100, step 4/8, loss = 0.2265
# epoch 79 / 100, step 5/8, loss = 0.2400
# epoch 79 / 100, step 6/8, loss = 0.2270
# epoch 79 / 100, step 7/8, loss = 0.2297
# epoch 79 / 100, step 8/8, loss = 0.2399
# epoch 80 / 100, step 1/8, loss = 0.2390
# epoch 80 / 100, step 2/8, loss = 0.2372
# epoch 80 / 100, step 3/8, loss = 0.2266
# epoch 80 / 100, step 4/8, loss = 0.2436
# epoch 80 / 100, step 5/8, loss = 0.2195
# epoch 80 / 100, step 6/8, loss = 0.2541
# epoch 80 / 100, step 7/8, loss = 0.2575
# epoch 80 / 100, step 8/8, loss = 0.2126
# epoch 81 / 100, step 1/8, loss = 0.2470
# epoch 81 / 100, step 2/8, loss = 0.2380
# epoch 81 / 100, step 3/8, loss = 0.2446
# epoch 81 / 100, step 4/8, loss = 0.2133
# epoch 81 / 100, step 5/8, loss = 0.2453
# epoch 81 / 100, step 6/8, loss = 0.2338
# epoch 81 / 100, step 7/8, loss = 0.2424
# epoch 81 / 100, step 8/8, loss = 0.2238
# epoch 82 / 100, step 1/8, loss = 0.2526
# epoch 82 / 100, step 2/8, loss = 0.2339
# epoch 82 / 100, step 3/8, loss = 0.2066
# epoch 82 / 100, step 4/8, loss = 0.2379
# epoch 82 / 100, step 5/8, loss = 0.2410
# epoch 82 / 100, step 6/8, loss = 0.2458
# epoch 82 / 100, step 7/8, loss = 0.2314
# epoch 82 / 100, step 8/8, loss = 0.2565
# epoch 83 / 100, step 1/8, loss = 0.2133
# epoch 83 / 100, step 2/8, loss = 0.2383
# epoch 83 / 100, step 3/8, loss = 0.2403
# epoch 83 / 100, step 4/8, loss = 0.2581
# epoch 83 / 100, step 5/8, loss = 0.2212
# epoch 83 / 100, step 6/8, loss = 0.2296
# epoch 83 / 100, step 7/8, loss = 0.2551
# epoch 83 / 100, step 8/8, loss = 0.2288
# epoch 84 / 100, step 1/8, loss = 0.2238
# epoch 84 / 100, step 2/8, loss = 0.2398
# epoch 84 / 100, step 3/8, loss = 0.2326
# epoch 84 / 100, step 4/8, loss = 0.2427
# epoch 84 / 100, step 5/8, loss = 0.2375
# epoch 84 / 100, step 6/8, loss = 0.2384
# epoch 84 / 100, step 7/8, loss = 0.2198
# epoch 84 / 100, step 8/8, loss = 0.3094
# epoch 85 / 100, step 1/8, loss = 0.2434
# epoch 85 / 100, step 2/8, loss = 0.2376
# epoch 85 / 100, step 3/8, loss = 0.2430
# epoch 85 / 100, step 4/8, loss = 0.2080
# epoch 85 / 100, step 5/8, loss = 0.2259
# epoch 85 / 100, step 6/8, loss = 0.2292
# epoch 85 / 100, step 7/8, loss = 0.2564
# epoch 85 / 100, step 8/8, loss = 0.2332
# epoch 86 / 100, step 1/8, loss = 0.2312
# epoch 86 / 100, step 2/8, loss = 0.2128
# epoch 86 / 100, step 3/8, loss = 0.2147
# epoch 86 / 100, step 4/8, loss = 0.2422
# epoch 86 / 100, step 5/8, loss = 0.2168
# epoch 86 / 100, step 6/8, loss = 0.2770
# epoch 86 / 100, step 7/8, loss = 0.2556
# epoch 86 / 100, step 8/8, loss = 0.2489
# epoch 87 / 100, step 1/8, loss = 0.2290
# epoch 87 / 100, step 2/8, loss = 0.2191
# epoch 87 / 100, step 3/8, loss = 0.2188
# epoch 87 / 100, step 4/8, loss = 0.2847
# epoch 87 / 100, step 5/8, loss = 0.2356
# epoch 87 / 100, step 6/8, loss = 0.2089
# epoch 87 / 100, step 7/8, loss = 0.2420
# epoch 87 / 100, step 8/8, loss = 0.2945
# epoch 88 / 100, step 1/8, loss = 0.2610
# epoch 88 / 100, step 2/8, loss = 0.2367
# epoch 88 / 100, step 3/8, loss = 0.2621
# epoch 88 / 100, step 4/8, loss = 0.2106
# epoch 88 / 100, step 5/8, loss = 0.2325
# epoch 88 / 100, step 6/8, loss = 0.2119
# epoch 88 / 100, step 7/8, loss = 0.2507
# epoch 88 / 100, step 8/8, loss = 0.2083
# epoch 89 / 100, step 1/8, loss = 0.2335
# epoch 89 / 100, step 2/8, loss = 0.2216
# epoch 89 / 100, step 3/8, loss = 0.2278
# epoch 89 / 100, step 4/8, loss = 0.2367
# epoch 89 / 100, step 5/8, loss = 0.2508
# epoch 89 / 100, step 6/8, loss = 0.2132
# epoch 89 / 100, step 7/8, loss = 0.2654
# epoch 89 / 100, step 8/8, loss = 0.2737
# epoch 90 / 100, step 1/8, loss = 0.2188
# epoch 90 / 100, step 2/8, loss = 0.2315
# epoch 90 / 100, step 3/8, loss = 0.2078
# epoch 90 / 100, step 4/8, loss = 0.2390
# epoch 90 / 100, step 5/8, loss = 0.2269
# epoch 90 / 100, step 6/8, loss = 0.2717
# epoch 90 / 100, step 7/8, loss = 0.2518
# epoch 90 / 100, step 8/8, loss = 0.2196
# epoch 91 / 100, step 1/8, loss = 0.2731
# epoch 91 / 100, step 2/8, loss = 0.2308
# epoch 91 / 100, step 3/8, loss = 0.2541
# epoch 91 / 100, step 4/8, loss = 0.2121
# epoch 91 / 100, step 5/8, loss = 0.2176
# epoch 91 / 100, step 6/8, loss = 0.2140
# epoch 91 / 100, step 7/8, loss = 0.2382
# epoch 91 / 100, step 8/8, loss = 0.2213
# epoch 92 / 100, step 1/8, loss = 0.2439
# epoch 92 / 100, step 2/8, loss = 0.1962
# epoch 92 / 100, step 3/8, loss = 0.2594
# epoch 92 / 100, step 4/8, loss = 0.2298
# epoch 92 / 100, step 5/8, loss = 0.2725
# epoch 92 / 100, step 6/8, loss = 0.2240
# epoch 92 / 100, step 7/8, loss = 0.2206
# epoch 92 / 100, step 8/8, loss = 0.2094
# epoch 93 / 100, step 1/8, loss = 0.2437
# epoch 93 / 100, step 2/8, loss = 0.2406
# epoch 93 / 100, step 3/8, loss = 0.2360
# epoch 93 / 100, step 4/8, loss = 0.2417
# epoch 93 / 100, step 5/8, loss = 0.2220
# epoch 93 / 100, step 6/8, loss = 0.2244
# epoch 93 / 100, step 7/8, loss = 0.2379
# epoch 93 / 100, step 8/8, loss = 0.1990
# epoch 94 / 100, step 1/8, loss = 0.2515
# epoch 94 / 100, step 2/8, loss = 0.1919
# epoch 94 / 100, step 3/8, loss = 0.2263
# epoch 94 / 100, step 4/8, loss = 0.2618
# epoch 94 / 100, step 5/8, loss = 0.2370
# epoch 94 / 100, step 6/8, loss = 0.2232
# epoch 94 / 100, step 7/8, loss = 0.2467
# epoch 94 / 100, step 8/8, loss = 0.2393
# epoch 95 / 100, step 1/8, loss = 0.2418
# epoch 95 / 100, step 2/8, loss = 0.2102
# epoch 95 / 100, step 3/8, loss = 0.2240
# epoch 95 / 100, step 4/8, loss = 0.2439
# epoch 95 / 100, step 5/8, loss = 0.2356
# epoch 95 / 100, step 6/8, loss = 0.2254
# epoch 95 / 100, step 7/8, loss = 0.2599
# epoch 95 / 100, step 8/8, loss = 0.1962
# epoch 96 / 100, step 1/8, loss = 0.2230
# epoch 96 / 100, step 2/8, loss = 0.2515
# epoch 96 / 100, step 3/8, loss = 0.2595
# epoch 96 / 100, step 4/8, loss = 0.2365
# epoch 96 / 100, step 5/8, loss = 0.2356
# epoch 96 / 100, step 6/8, loss = 0.2142
# epoch 96 / 100, step 7/8, loss = 0.2069
# epoch 96 / 100, step 8/8, loss = 0.2684
# epoch 97 / 100, step 1/8, loss = 0.2573
# epoch 97 / 100, step 2/8, loss = 0.2414
# epoch 97 / 100, step 3/8, loss = 0.2398
# epoch 97 / 100, step 4/8, loss = 0.2220
# epoch 97 / 100, step 5/8, loss = 0.2096
# epoch 97 / 100, step 6/8, loss = 0.2141
# epoch 97 / 100, step 7/8, loss = 0.2487
# epoch 97 / 100, step 8/8, loss = 0.2454
# epoch 98 / 100, step 1/8, loss = 0.2480
# epoch 98 / 100, step 2/8, loss = 0.2419
# epoch 98 / 100, step 3/8, loss = 0.2342
# epoch 98 / 100, step 4/8, loss = 0.2304
# epoch 98 / 100, step 5/8, loss = 0.2154
# epoch 98 / 100, step 6/8, loss = 0.2210
# epoch 98 / 100, step 7/8, loss = 0.2422
# epoch 98 / 100, step 8/8, loss = 0.2120
# epoch 99 / 100, step 1/8, loss = 0.2269
# epoch 99 / 100, step 2/8, loss = 0.2115
# epoch 99 / 100, step 3/8, loss = 0.2442
# epoch 99 / 100, step 4/8, loss = 0.2274
# epoch 99 / 100, step 5/8, loss = 0.2624
# epoch 99 / 100, step 6/8, loss = 0.2495
# epoch 99 / 100, step 7/8, loss = 0.2111
# epoch 99 / 100, step 8/8, loss = 0.2306
# epoch 100 / 100, step 1/8, loss = 0.2109
# epoch 100 / 100, step 2/8, loss = 0.2475
# epoch 100 / 100, step 3/8, loss = 0.2367
# epoch 100 / 100, step 4/8, loss = 0.2282
# epoch 100 / 100, step 5/8, loss = 0.2249
# epoch 100 / 100, step 6/8, loss = 0.2332
# epoch 100 / 100, step 7/8, loss = 0.2627
# epoch 100 / 100, step 8/8, loss = 0.1815

# %%
with torch.no_grad():
    n_corrects = 0
    n_samples = 0
    for i, (inputs, targets) in enumerate(train_loader):
        inputs = inputs.to(device)
        #print(inputs)
        targets = targets.to(device,dtype=torch.int64)
        outputs = model(inputs)
        #print(outputs)
        
        _,prediction = torch.max(outputs,1)
        #print(prediction)
        n_samples+=targets.shape[0]
        n_corrects += (prediction == targets).sum().item()
        
    acc = 100*n_corrects/n_samples
    print(f'accuracy equals {acc}')
# Out:
# accuracy equals 91.85341660543718
